# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulHanoos/Statistical-Learning-e20128/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q3) Transformer Failiures

# %% [markdown]
# In a certain electricity distribution district, the number of emergency transformer failures reported in a single day is modeled as a discrete random variable $X$. Assume that $X$ takes values in the set $\{0,1,2,3\}$, with probabilities
#
# $$
# P(X=0)=0.50,\qquad P(X=1)=0.30,\qquad P(X=2)=0.15,\qquad P(X=3)=0.05.
# $$
#
# 1. Construct a probability space $(\Omega,\mathfrak F,P)$ suitable for this model.
# 2. Define $X$ as a random variable on this space.
# 3. Determine the probability mass function of $X$.
# 4. Compute the expectation $E[X]$.
# 5. Compute the variance $\mathrm{Var}(X)$.
# 6. Find $P(X\ge 1)$ and $P(X\ge 2)$.
# 7. Briefly explain the practical meaning of the expectation and variance in this setting.

# %% [markdown]
# #1

# %% [markdown]
# ### Construction of the Probability Space $(\Omega, \mathcal{F}, P)$
#
# **1. The Sample Space ($\Omega$):**
# Since the random variable $X$ directly tracks the specific system states, we define the sample space $\Omega$ as the finite set of all possible atomic outcomes:
# $$\Omega = \{0, 1, 2, 3\}$$
#
# In this setup, each distinct outcome $\omega \in \Omega$ directly represents the exact number of emergency transformer failures reported within a single operational day.
#
# **2. The Sigma-Algebra ($\mathcal{F}$):**
# Because the underlying sample space $\Omega$ is finite, we can safely and naturally utilize the complete power set of $\Omega$ to construct our collection of measurable events:
# $$\mathcal{F} = \mathcal{P}(\Omega)$$
#
# Explicitly expanding this power set provides a robust $\sigma$-algebra containing all $2^4 = 16$ possible experimental configurations:
# $$\mathcal{F} = \{ \emptyset, \{0\}, \{1\}, \{2\}, \{3\}, \{0,1\}, \{0,2\}, \{0,3\}, \{1,2\}, \{1,3\}, \{2,3\}, \{0,1,2\}, \{0,1,3\}, \{0,2,3\}, \{1,2,3\}, \Omega \}$$
#
# **3. The Probability Measure ($P$):**
# The probability measure $P : \mathcal{F} \to [0,1]$ is formally established by mapping the given operational likelihoods directly to each elementary singleton event:
# $$P(\{0\}) = 0.50$$
# $$P(\{1\}) = 0.30$$
# $$P(\{2\}) = 0.15$$
# $$P(\{3\}) = 0.05$$
#
# By applying the fundamental axiom of finite additivity for disjoint sets, the total probability of any arbitrary composite event $A \in \mathcal{F}$ is computed systematically by summing the weights of its individual elements:
# $$\boxed{P(A) = \sum_{\omega \in A} P(\{\omega\})}$$

# %% [markdown]
# #2

# %% [markdown]
# ### Formal Definition of the Random Variable $X$
#
#
# A random variable on a probability space $(\Omega, \mathcal{F}, P)$ is defined as a measurable function mapping elements from the sample space to the real numbers. We define the random variable $X$ by:
# $$X : \Omega \to \mathbb{R}$$
#
# under the explicit rule:
# $$X(\omega) = \omega, \quad \forall \omega \in \Omega$$
#
#
# Since the underlying sample space consists of the finite atomic states $\Omega = \{0, 1, 2, 3\}$, evaluating this functional rule across all individual sample points maps them as:
# $$X(0) = 0, \quad X(1) = 1, \quad X(2) = 2, \quad X(3) = 3$$
#
#  $X$ simply returns the exact count of emergency transformer failures recorded during a single operational day.

# %% [markdown]
# #3

# %% [markdown]
# ### Probability Mass Function of $X$
#
# The probability mass function (PMF) of a discrete random variable $X$ gives the probability assigned to each possible value of $X$. It is defined as
# $$
# p_X(x)=P(X=x)
# $$
#
# Since the random variable $X$ represents the number of emergency transformer failures in a single day, it takes values in the finite set
# $$
# \{0,1,2,3\}.
# $$
#
# Using the given probabilities, the PMF of $X$ is
#
# $$
# p_X(0)=P(X=0)=0.50
# $$
#
# $$
# p_X(1)=P(X=1)=0.30
# $$
#
# $$
# p_X(2)=P(X=2)=0.15
# $$
#
# $$
# p_X(3)=P(X=3)=0.05
# $$
#
# Therefore, the probability mass function can be written as
#
# $$
# \boxed{
# p_X(x)=
# \begin{cases}
# 0.50, & x=0,\\
# 0.30, & x=1,\\
# 0.15, & x=2,\\
# 0.05, & x=3,\\
# 0, & \text{otherwise}.
# \end{cases}
# }
# $$
#
# To verify that this is a valid PMF, we check the normalization condition:
# $$
# \sum_{x\in\{0,1,2,3\}}p_X(x)
# =
# 0.50+0.30+0.15+0.05
# =
# 1.
# $$
#
# Hence, $p_X$ is a valid probability mass function.

# %% [markdown]
# #4

# %% [markdown]
# ### Expectation of $X$
#
# The expectation of a discrete random variable $X$ is defined as
#
# $$
# E[X]=\sum_x xP(X=x).
# $$
#
# Since $X$ takes values in $\{0,1,2,3\}$, we have
#
# $$
# E[X]
# =
# 0.P(X=0)+1.P(X=1)+2.P(X=2)+3.P(X=3).
# $$
#
# Substituting the given probabilities,
#
# $$
# E[X]
# =
# 0.(0.50)+1.(0.30)+2.(0.15)+3.(0.05).
# $$
#
# Thus,
#
# $$
# E[X]
# =
# 0+0.30+0.30+0.15
# =
# 0.75.
# $$
#
# Therefore,
#
# $$
# \boxed{E[X]=0.75}.
# $$
#
# Hence, the expected number of emergency transformer failures reported in a single day is $0.75$.

# %%
# Values of X
x_values = [0, 1, 2, 3]

# Corresponding probabilities
probabilities = [0.50, 0.30, 0.15, 0.05]

# Expectation E[X] = sum x * P(X=x)
expected_value = sum(x * p for x, p in zip(x_values, probabilities))

print("E[X] =", expected_value)
# Out:
# E[X] = 0.75

# %% [markdown]
# #5

# %% [markdown]
# ### Variance of $X$
#
# The variance of a discrete random variable $X$ is defined as
#
# $$
# \operatorname{Var}(X)=E[X^2]-(E[X])^2.
# $$
#
# From the previous calculation,
#
# $$
# E[X]=0.75.
# $$
#
# Now,
#
# $$
# E[X^2]=\sum_x x^2P(X=x).
# $$
#
# Since $X$ takes values in $\{0,1,2,3\}$,
#
# $$
# E[X^2]
# =
# 0^2.(0.50)+1^2.(0.30)+2^.2.(0.15)+3^2.(0.05).
# $$
#
# Thus,
#
# $$
# E[X^2]
# =
# 0+0.30+4(0.15)+9(0.05).
# $$
#
# Therefore,
#
# $$
# E[X^2]
# =
# 0.30+0.60+0.45
# =
# 1.35.
# $$
#
# Hence,
#
# $$
# \operatorname{Var}(X)
# =
# 1.35-(0.75)^2.
# $$
#
# So,
#
# $$
# \operatorname{Var}(X)
# =
# 1.35-0.5625
# =
# 0.7875.
# $$
#
# Therefore,
#
# $$
# \boxed{\operatorname{Var}(X)=0.7875}.
# $$

# %%
import numpy as np

x_values = np.array([0, 1, 2, 3])
probabilities = np.array([0.50, 0.30, 0.15, 0.05])

expected_value = np.sum(x_values * probabilities)
expected_square = np.sum((x_values**2) * probabilities)

variance = expected_square - expected_value**2

print("E[X] =", expected_value)
print("E[X^2] =", expected_square)
print("Var(X) =", variance)
# Out:
# E[X] = 0.75
# E[X^2] = 1.3499999999999999
# Var(X) = 0.7874999999999999

# %% [markdown]
# #6

# %% [markdown]
# ### Computing $P(X\geq 1)$ and $P(X\geq 2)$
#
# Using the probability mass function of $X$,
#
# $$
# P(X=0)=0.50,\quad P(X=1)=0.30,\quad P(X=2)=0.15,\quad P(X=3)=0.05.
# $$
#
# First,
#
# $$
# P(X\geq 1)
# =
# P(X=1)+P(X=2)+P(X=3).
# $$
#
# Therefore,
#
# $$
# P(X\geq 1)
# =
# 0.30+0.15+0.05
# =
# 0.50.
# $$
#
# Hence,
#
# $$
# \boxed{P(X\geq 1)=0.50}.
# $$
#
# Next,
#
# $$
# P(X\geq 2)
# =
# P(X=2)+P(X=3).
# $$
#
# Therefore,
#
# $$
# P(X\geq 2)
# =
# 0.15+0.05
# =
# 0.20.
# $$
#
# Hence,
#
# $$
# \boxed{P(X\geq 2)=0.20}.
# $$

# %%
x_values = [0, 1, 2, 3]
probabilities = [0.50, 0.30, 0.15, 0.05]

P_X_ge_1 = sum(p for x, p in zip(x_values, probabilities) if x >= 1)
P_X_ge_2 = sum(p for x, p in zip(x_values, probabilities) if x >= 2)

print("P(X >= 1) =", P_X_ge_1)
print("P(X >= 2) =", P_X_ge_2)
# Out:
# P(X >= 1) = 0.5
# P(X >= 2) = 0.2

# %% [markdown]
# #7

# %% [markdown]
# ### Practical Meaning of the Expectation and Variance
#
# The expectation of \(X\) is
#
#
#
# This means that, over a long period of time, the electricity distribution district expects an average of \(0.75\) emergency transformer failures per day. It does not mean that exactly \(0.75\) failures occur on any single day. Rather, it represents the long-run average number of failures per day.
#
# The variance of \(X\) is
#
#
# The variance measures how much the daily number of transformer failures tends to vary around the mean value \(0.75\). A larger variance would indicate more fluctuation in the number of daily failures, while a smaller variance would indicate that the number of failures is usually close to the average.
#
# In practical terms, the expectation helps estimate the average daily workload, while the variance helps understand the uncertainty or variability in emergency failure occurrences. These quantities are useful for planning repair teams, spare equipment, maintenance schedules, and emergency response resources.

# %% [markdown]
# # Q4) Probability of Defective Items

# %% [markdown]
# In a manufacturing process, the proportion of defective items in a large batch produced on a given day is modeled by a continuous random variable $X$. Since $X$ represents a proportion, it takes values in the interval $[0,1]$. Suppose that $X$ has a Beta distribution with parameters $\alpha=2$ and $\beta=18$, so that its density is
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x^{1}(1-x)^{17}, & 0<x<1,\\\
# 0, & \text{otherwise},
# \end{cases}
# $$
#
# where $B(2,18)$ is the Beta function.
#
# Answer the following:
#
# 1. Construct a probability space $(\Omega,\mathfrak F,P)$ suitable for this model.
#
# 2. Define $X$ as a continuous random variable on this space.
#
# 3. Write down the probability density function of $X$.
#
# 4. Verify that $f$ is a valid probability density function.
#
# 5. Compute the expectation $E[X]$.
#
# 6. Compute the variance $\mathrm{Var}(X)$.
#
# 7. Find the probability that the defective proportion is at most $0.10$, that is, compute
#
# $$
# P(X\le 0.10).
# $$
#
# You may leave your answer in Beta integral form.
#
# 8. Find the probability that the defective proportion lies between $0.05$ and $0.15$, that is, compute
#
# $$
# P(0.05\le X\le 0.15).
# $$
#
# You may leave your answer in integral form.
#
# 9. Briefly explain why a Beta distribution is a reasonable model for this situation.
#
# 10. Interpret the expectation and variance in the context of production quality.

# %% [markdown]
# #1

# %% [markdown]
# ### Construction of the Probability Space $(\Omega,\mathcal{F},P)$
#
# The random variable \(X\) represents the proportion of defective items in a large batch. Since \(X\) is a proportion, it takes values in the interval \([0,1]\). Therefore, we define the  **sample space** as
#
# $$
# \Omega=[0,1].
# $$
#
# Each outcome \(ω∈Ω\) represents a possible defective proportion in the batch.
#
# Since the sample space is a continuous interval, we take the sigma-algebra to be the Borel sigma-algebra on \([0,1]\):
#
# $$
# \mathcal{F}=\mathcal{B}([0,1]).
# $$
#
# The probability measure \(P\) is induced by the Beta distribution with parameters \(α=2\) and \(β=18\). The density function is
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x(1-x)^{17}, & 0<x<1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Thus, for any event A, the probability measure is defined by
#
# $$
# P(A)=\int_A f(x)\,dx.
# $$
#
# Equivalently,
#
# $$
# P(A)=
# \int_A
# \dfrac{1}{B(2,18)}
# x(1-x)^{17}
# \,dx.
# $$
#
# Therefore, a suitable probability space is
#
# $$
# \boxed{
# (\Omega,\mathcal{F},P)
# =
# \left(
# [0,1],
# \mathcal{B}([0,1]),
# P
# \right)
# }.
# $$

# %% [markdown]
# #2

# %% [markdown]
# ### Definition of the Continuous Random Variable $X$
#
# Define the random variable
#
# $$
# X:\Omega\to\mathbb{R}
# $$
#
# by
#
# $$
# X(\omega)=\omega,\qquad \omega\in\Omega.
# $$
#
# Since
#
# $$
# \Omega=[0,1],
# $$
#
# we have
#
# $$
# X(\omega)=\omega,\qquad 0\leq \omega\leq 1.
# $$
#
# Thus, $X$ directly records the proportion of defective items in the batch.
#
#
#
# Since $X$ maps from $([0,1],\mathcal{B}([0,1]))$ to $(\mathbb{R},\mathcal{B}(\mathbb{R}))$ and the identity map is Borel measurable, $X$ is a valid continuous random variable on this probability space.

# %% [markdown]
# #3

# %% [markdown]
# ### Probability Density Function of $X$
#
# Since $X$ follows a Beta distribution with parameters $\alpha=2$ and $\beta=18$, its probability density function is
#
# $$
# f_X(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x^{2-1}(1-x)^{18-1}, & 0<x<1,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Simplifying the powers gives
#
# $$
# f_X(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x(1-x)^{17}, & 0<x<1,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Therefore,
#
# $$
# \boxed{
# f_X(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x(1-x)^{17}, & 0<x<1,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# }
# $$
#
# where $B(2,18)$ is the Beta function.

# %% [markdown]
# #4

# %% [markdown]
# ### Verification that $f$ is a Valid Probability Density Function
#
# To verify that $f$ is a valid probability density function, we must check two conditions:
#
# $$
# f(x)\geq 0
# $$
#
# for all $x$, and
#
# $$
# \int_{-\infty}^{\infty} f(x)\,dx=1.
# $$
#
# The density is given by
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{1}{B(2,18)}x(1-x)^{17}, & 0<x<1,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# First, for $0<x<1$, we have
#
# $$
# x>0
# $$
#
# and
#
# $$
# (1-x)^{17}>0.
# $$
#
# Also, since the Beta function is positive,
#
# $$
# B(2,18)>0.
# $$
#
# Therefore,
#
# $$
# f(x)\geq 0.
# $$
#
# Outside the interval $(0,1)$, we have
#
# $$
# f(x)=0.
# $$
#
# Hence, $f$ is non-negative everywhere.
#
# Next, we verify that the total integral is equal to $1$:
#
# $$
# \int_{-\infty}^{\infty} f(x)\,dx
# =
# \int_0^1 \frac{1}{B(2,18)}x(1-x)^{17}\,dx.
# $$
#
# Taking the constant outside,
#
# $$
# \int_{-\infty}^{\infty} f(x)\,dx
# =
# \frac{1}{B(2,18)}
# \int_0^1 x(1-x)^{17}\,dx.
# $$
#
# By the definition of the Beta function,
#
# $$
# B(2,18)
# =
# \int_0^1 x^{2-1}(1-x)^{18-1}\,dx.
# $$
#
# Thus,
#
# $$
# B(2,18)
# =
# \int_0^1 x(1-x)^{17}\,dx.
# $$
#
# Therefore,
#
# $$
# \int_{-\infty}^{\infty} f(x)\,dx
# =
# \frac{1}{B(2,18)}B(2,18)
# =
# 1.
# $$
#
# Since $f(x)\geq 0$ for all $x$ and its total integral is $1$, $f$ is a valid probability density function.
#
# $$
# \boxed{f \text{ is a valid probability density function.}}
# $$

# %% [markdown]
# #5

# %% [markdown]
# ### Expectation of $X$
#
# Since $X$ follows a Beta distribution with parameters $\alpha=2$ and $\beta=18$, we use the expectation formula for a Beta random variable:
#
# $$
# E[X]=\frac{\alpha}{\alpha+\beta}.
# $$
#
# Substituting $\alpha=2$ and $\beta=18$,
#
# $$
# E[X]=\frac{2}{2+18}.
# $$
#
# Thus,
#
# $$
# E[X]=\frac{2}{20}=0.10.
# $$
#
# Therefore,
#
# $$
# \boxed{E[X]=0.10}.
# $$
#
# Hence, the expected defective proportion in the batch is $0.10$, or $10\%$.

# %% [markdown]
# #6

# %% [markdown]
# ### Variance of $X$
#
# Since $X$ follows a Beta distribution with parameters $\alpha=2$ and $\beta=18$, the variance of a Beta random variable is given by
#
# $$
# \operatorname{Var}(X)
# =
# \frac{\alpha\beta}{(\alpha+\beta)^2(\alpha+\beta+1)}.
# $$
#
# Substituting $\alpha=2$ and $\beta=18$,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{(2)(18)}{(2+18)^2(2+18+1)}.
# $$
#
# Thus,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{36}{20^2(21)}.
# $$
#
# Therefore,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{36}{8400}
# =
# 0.0042857.
# $$
#
# Hence,
#
# $$
# \boxed{\operatorname{Var}(X)\approx 0.00429}.
# $$
#
# This means that the defective proportion varies around its mean value of $0.10$, but the variation is relatively small.

# %%
# Beta distribution parameters
alpha = 2
beta = 18

# Expectation
expected_value = alpha / (alpha + beta)

# Variance
variance = (alpha * beta) / ((alpha + beta)**2 * (alpha + beta + 1))

print("E[X] =", expected_value)
print("Var(X) =", variance)
# Out:
# E[X] = 0.1
# Var(X) = 0.004285714285714286

# %% [markdown]
# #7

# %% [markdown]
# ### Probability that the defective proportion is at most $0.10$
#
# Since $X\sim \text{Beta}(2,18)$, its density is
#
# $$
# f_X(x)=\frac{1}{B(2,18)}x(1-x)^{17},\qquad 0<x<1.
# $$
#
# Therefore,
#
# $$
# P(X\leq 0.10)
# =
# \int_0^{0.10} f_X(x)\,dx.
# $$
#
# Substituting the density,
#
# $$
# P(X\leq 0.10)
# =
# \int_0^{0.10}
# \frac{1}{B(2,18)}
# x(1-x)^{17}
# \,dx.
# $$
#
# Thus,
#
# $$
# \boxed{
# P(X\leq 0.10)
# =
# \int_0^{0.10}
# \frac{1}{B(2,18)}
# x(1-x)^{17}
# \,dx
# }.
# $$

# %%
from scipy.stats import beta

alpha = 2
beta_param = 18

probability = beta.cdf(0.10, alpha, beta_param)

print("P(X <= 0.10) =", probability)
# Out:
# P(X <= 0.10) = 0.5797350211684026

# %% [markdown]
# #8

# %% [markdown]
# ### Probability that the defective proportion lies between $0.05$ and $0.15$
#
# Since $X\sim \text{Beta}(2,18)$, its probability density function is
#
# $$
# f_X(x)=\frac{1}{B(2,18)}x(1-x)^{17},\qquad 0<x<1.
# $$
#
# Therefore,
#
# $$
# P(0.05\leq X\leq 0.15)
# =
# \int_{0.05}^{0.15} f_X(x)\,dx.
# $$
#
# Substituting the density,
#
# $$
# P(0.05\leq X\leq 0.15)
# =
# \int_{0.05}^{0.15}
# \frac{1}{B(2,18)}
# x(1-x)^{17}
# \,dx.
# $$
#
# Thus,
#
# $$
# \boxed{
# P(0.05\leq X\leq 0.15)
# =
# \int_{0.05}^{0.15}
# \frac{1}{B(2,18)}
# x(1-x)^{17}
# \,dx
# }.
# $$

# %%
from scipy.stats import beta

alpha = 2
beta_param = 18

probability = beta.cdf(0.15, alpha, beta_param) - beta.cdf(0.05, alpha, beta_param)

print("P(0.05 <= X <= 0.15) =", probability)
# Out:
# P(0.05 <= X <= 0.15) = 0.5562154887900577

# %% [markdown]
# #9

# %% [markdown]
# ### Practical Reason for Using a Beta Distribution
#
# A Beta distribution is a reasonable model in this situation because the random variable \(X\) represents a proportion of defective items. A proportion must lie between \(0\) and \(1\), and the Beta distribution is naturally defined on the interval \([0,1]\).
#
# The Beta distribution is also flexible. By changing the parameters \(𝛂) and \(β\), it can model different possible shapes for proportions, including low defect rates, high defect rates, and skewed distributions.
#
# In this case,
#
# $$
# X\sim \text{Beta}(2,18).
# $$
#
# The expected value is
#
# $$
# E[X]=\frac{2}{2+18}=0.10.
# $$
#
# Thus, the distribution is centered around a defective proportion of approximately \(10\%\). Since \(β=18\) is much larger than \(𝛂=2\), the distribution places more probability near smaller values of \(X\). This is realistic for a manufacturing process where the proportion of defective items is expected to be relatively low.

# %% [markdown]
# #10

# %% [markdown]
# ### Interpretation of Expectation and Variance
#
# The expectation is
#
# $$
# E[X]=0.10.
# $$
#
# This means that the average defective proportion is expected to be about \(10\%\). In practical terms, the factory expects about \(10\) defective items out of every \(100\) items produced.
#
# The variance is
#
# $$
# \operatorname{Var}(X)\approx 0.00429.
# $$
#
# The variance measures how much the defective proportion changes from batch to batch. A small variance means that the defective proportion is usually close to the average value of \(10\%\). A large variance would mean that the defective proportion changes a lot across batches.
#
# Therefore, the expectation describes the average production quality level, while the variance describes the consistency of that quality.

# %% [markdown]
# # Q5) Expected Project Completion Time

# %% [markdown]
# A construction company is estimating the time required to install a backup generator at a hospital. Let $X$ denote the number of hours needed to complete the installation. Based on expert judgment, the shortest possible time is $4$ hours, the longest possible time is $10$ hours, and the most likely completion time is $6$ hours. Assume that $X$ follows a Triangular distribution with parameters $a=4$, $b=10$, and $c=6$.
#
# Answer the following:
#
# 1. Specify the support of $X$.
#
# 2. Write down the probability density function $f_X(x)$.
#
# 3. Verify that $f_X$ integrates to $1$ over its support.
#
# 4. Compute the expectation $E[X]$.
#
# 5. Compute the variance $\mathrm{Var}(X)$.
#
# 6. Interpret the values of $a$, $b$, and $c$ in the context of this problem.
#
# 7. Explain briefly why a Triangular distribution is a reasonable model in this setting.
#
# 8. Compute the probability that the installation takes at most $5$ hours, that is, compute
#
# $$
# P(X \leq 5).
# $$
#
# 9. Compute the probability that the installation takes between $5$ and $8$ hours, that is, compute
#
# $$
# P(5 \leq X \leq 8).
# $$
#
# 10. Briefly explain how this model could be used in project planning or sensitivity analysis.

# %% [markdown]
# #1

# %% [markdown]
# ### Support of $X$
#
# The support of a random variable is the set of all possible values that the random variable can take.
#
# For the Triangular distribution with parameters
#
# $$
# a=4,\qquad b=10,\qquad c=6,
# $$
#
# the parameter \(a\) represents the shortest possible time, \(b\) represents the longest possible time, and \(c\) represents the most likely time.
#
# Therefore, the support of \(X\) is
#
# $$
# 4\leq X\leq 10.
# $$
#
# Equivalently,
#
# $$
# \boxed{X\in[4,10]}.
# $$
#
# Thus, the generator installation time can range from \(4\) hours to \(10\) hours.

# %% [markdown]
# #2

# %% [markdown]
# ### Probability Density Function of $X$
#
# Since $X$ follows a Triangular distribution with parameters
#
# $$
# a=4,\qquad b=10,\qquad c=6,
# $$
#
# the probability density function is
#
# $$
# f_X(x)=
# \begin{cases}
# \dfrac{2(x-a)}{(b-a)(c-a)}, & a\leq x\leq c,\\[6pt]
# \dfrac{2(b-x)}{(b-a)(b-c)}, & c<x\leq b,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Substituting \(a=4\), \(b=10\), and \(c=6\),
#
# $$
# f_X(x)=
# \begin{cases}
# \dfrac{2(x-4)}{(10-4)(6-4)}, & 4\leq x\leq 6,\\[6pt]
# \dfrac{2(10-x)}{(10-4)(10-6)}, & 6<x\leq 10,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Simplifying,
#
# $$
# \boxed{
# f_X(x)=
# \begin{cases}
# \dfrac{x-4}{6}, & 4\leq x\leq 6,\\[6pt]
# \dfrac{10-x}{12}, & 6<x\leq 10,\\[6pt]
# 0, & \text{otherwise}.
# \end{cases}
# }
# $$

# %% [markdown]
# #3

# %% [markdown]
# ### Verification that $f_X$ Integrates to $1$
#
# To verify that $f_X$ is a valid probability density function, we need to show that
#
# $$
# \int_{4}^{10} f_X(x)\,dx=1.
# $$
#
# The density is
#
# $$
# f_X(x)=
# \begin{cases}
# \dfrac{x-4}{6}, & 4\leq x\leq 6,\\[6pt]
# \dfrac{10-x}{12}, & 6<x\leq 10.
# \end{cases}
# $$
#
# Therefore,
#
# $$
# \int_{4}^{10} f_X(x)\,dx
# =
# \int_{4}^{6}\frac{x-4}{6}\,dx
# +
# \int_{6}^{10}\frac{10-x}{12}\,dx.
# $$
#
# First,
#
# $$
# \int_{4}^{6}\frac{x-4}{6}\,dx
# =
# \frac{1}{6}
# \left[
# \frac{(x-4)^2}{2}
# \right]_{4}^{6}.
# $$
#
# Thus,
#
# $$
# \int_{4}^{6}\frac{x-4}{6}\,dx
# =
# \frac{1}{6}\cdot \frac{(6-4)^2}{2}
# =
# \frac{1}{6}\cdot\frac{4}{2}
# =
# \frac{1}{3}.
# $$
#
# Next,
#
# $$
# \int_{6}^{10}\frac{10-x}{12}\,dx
# =
# \frac{1}{12}
# \left[
# 10x-\frac{x^2}{2}
# \right]_{6}^{10}.
# $$
#
# Therefore,
#
# $$
# \int_{6}^{10}\frac{10-x}{12}\,dx
# =
# \frac{1}{12}
# \left[
# \left(100-50\right)-\left(60-18\right)
# \right].
# $$
#
# So,
#
# $$
# \int_{6}^{10}\frac{10-x}{12}\,dx
# =
# \frac{1}{12}(50-42)
# =
# \frac{8}{12}
# =
# \frac{2}{3}.
# $$
#
# Hence,
#
# $$
# \int_{4}^{10} f_X(x)\,dx
# =
# \frac{1}{3}+\frac{2}{3}
# =
# 1.
# $$
#
# Therefore, $f_X$ integrates to $1$ over its support, so it is a valid probability density function.

# %% [markdown]
# #4

# %% [markdown]
# ### Expectation of $X$
#
# For a Triangular distribution with parameters \(a\), \(b\), and \(c\), the expectation is
#
# $$
# E[X]=\frac{a+b+c}{3}.
# $$
#
# Here,
#
# $$
# a=4,\qquad b=10,\qquad c=6.
# $$
#
# Therefore,
#
# $$
# E[X]=\frac{4+10+6}{3}.
# $$
#
# Thus,
#
# $$
# E[X]=\frac{20}{3}.
# $$
#
# Hence,
#
# $$
# \boxed{E[X]=\frac{20}{3}\approx 6.67\text{ hours}}.
# $$
#
# Therefore, the expected generator installation time is approximately \(6.67\) hours.

# %% [markdown]
# #5

# %% [markdown]
# ### Variance of $X$
#
# For a Triangular distribution with parameters \(a\), \(b\), and \(c\), the variance is
#
# $$
# \operatorname{Var}(X)
# =
# \frac{a^2+b^2+c^2-ab-ac-bc}{18}.
# $$
#
# Here,
#
# $$
# a=4,\qquad b=10,\qquad c=6.
# $$
#
# Therefore,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{4^2+10^2+6^2-(4)(10)-(4)(6)-(10)(6)}{18}.
# $$
#
# Thus,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{16+100+36-40-24-60}{18}.
# $$
#
# So,
#
# $$
# \operatorname{Var}(X)
# =
# \frac{28}{18}
# =
# \frac{14}{9}.
# $$
#
# Hence,
#
# $$
# \boxed{\operatorname{Var}(X)=\frac{14}{9}\approx 1.56\text{ hours}^2}.
# $$

# %% [markdown]
# #6

# %% [markdown]
# ### Interpretation of $a$, $b$, and $c$
#
# For the triangular distribution,
#
# $$
# a=4,\qquad b=10,\qquad c=6.
# $$
#
# The parameter \(a\) represents the minimum possible value of the random variable \(X\). In this context,
#
# $$
# a=4
# $$
#
# means that the shortest possible time required to install the backup generator is \(4\) hours.
#
# The parameter \(b\) represents the maximum possible value of \(X\). In this context,
#
# $$
# b=10
# $$
#
# means that the longest possible time required to complete the installation is \(10\) hours.
#
# The parameter \(c\) represents the mode, or the most likely value of \(X\). In this context,
#
# $$
# c=6
# $$
#
# means that the most likely installation time is \(6\) hours.
#
# Therefore, the company estimates that the generator installation will take at least \(4\) hours, at most \(10\) hours, and most likely around \(6\) hours.

# %% [markdown]
# #7

# %% [markdown]
# ### Reason for Using a Triangular Distribution
#
# A Triangular distribution is a reasonable model in this setting because the company may not have enough historical data to estimate a more complex distribution, but it has three useful expert estimates:
#
# $$
# a=4,
# $$
#
# which represents the shortest possible installation time,
#
# $$
# b=10,
# $$
#
# which represents the longest possible installation time, and
#
# $$
# c=6,
# $$
#
# which represents the most likely installation time.
#
# The Triangular distribution is commonly used when only the minimum value, maximum value, and most likely value are known. It assigns more probability near the most likely value and less probability near the extreme values.
#
# Therefore, it is suitable for modeling the uncertain time required to install the backup generator at the hospital.

# %% [markdown]
# #8

# %% [markdown]
# ### Probability that the Installation Takes at Most $5$ Hours
#
# We want to compute
#
# $$
# P(X\leq 5).
# $$
#
# For the Triangular distribution with parameters
#
# $$
# a=4,\qquad b=10,\qquad c=6,
# $$
#
# the value \(5\) lies between \(a=4\) and \(c=6\). Therefore, we use the first part of the cumulative distribution function:
#
# $$
# P(X\leq x)
# =
# \frac{(x-a)^2}{(b-a)(c-a)},
# \qquad a\leq x\leq c.
# $$
#
# Substituting \(x=5\), \(a=4\), \(b=10\), and \(c=6\),
#
# $$
# P(X\leq 5)
# =
# \frac{(5-4)^2}{(10-4)(6-4)}.
# $$
#
# Thus,
#
# $$
# P(X\leq 5)
# =
# \frac{1^2}{(6)(2)}
# =
# \frac{1}{12}.
# $$
#
# Therefore,
#
# $$
# \boxed{P(X\leq 5)=\frac{1}{12}\approx 0.0833}.
# $$
#
# Hence, there is approximately an \(8.33\%\) chance that the installation takes at most \(5\) hours.

# %%
# Triangular distribution parameters
a = 4   # minimum time
b = 10  # maximum time
c = 6   # most likely time

# Value to calculate P(X <= x)
x = 5

# CDF for triangular distribution
if x < a:
    probability = 0
elif a <= x <= c:
    probability = ((x - a) ** 2) / ((b - a) * (c - a))
elif c < x <= b:
    probability = 1 - ((b - x) ** 2) / ((b - a) * (b - c))
else:
    probability = 1

print("P(X <= 5) =", probability)
# Out:
# P(X <= 5) = 0.08333333333333333

# %% [markdown]
# #9

# %% [markdown]
# ### Probability that the Installation Takes Between $5$ and $8$ Hours
#
# We want to compute
#
# $$
# P(5\leq X\leq 8).
# $$
#
# This can be written using the cumulative distribution function as
#
# $$
# P(5\leq X\leq 8)=F(8)-F(5).
# $$
#
# For the Triangular distribution with parameters
#
# $$
# a=4,\qquad b=10,\qquad c=6,
# $$
#
# the value \(5\) lies between \(a=4\) and \(c=6\). Therefore,
#
# $$
# F(5)=\frac{(5-a)^2}{(b-a)(c-a)}.
# $$
#
# Substituting the values,
#
# $$
# F(5)=\frac{(5-4)^2}{(10-4)(6-4)}
# =
# \frac{1}{12}.
# $$
#
# The value \(8\) lies between \(c=6\) and \(b=10\). Therefore,
#
# $$
# F(8)=1-\frac{(b-8)^2}{(b-a)(b-c)}.
# $$
#
# Substituting the values,
#
# $$
# F(8)
# =
# 1-\frac{(10-8)^2}{(10-4)(10-6)}.
# $$
#
# Thus,
#
# $$
# F(8)
# =
# 1-\frac{4}{24}
# =
# 1-\frac{1}{6}
# =
# \frac{5}{6}.
# $$
#
# Hence,
#
# $$
# P(5\leq X\leq 8)
# =
# F(8)-F(5).
# $$
#
# Therefore,
#
# $$
# P(5\leq X\leq 8)
# =
# \frac{5}{6}-\frac{1}{12}
# =
# \frac{10}{12}-\frac{1}{12}
# =
# \frac{9}{12}
# =
# \frac{3}{4}.
# $$
#
# Thus,
#
# $$
# \boxed{P(5\leq X\leq 8)=0.75}.
# $$
#
# So there is a \(75\%\) chance that the installation takes between \(5\) and \(8\) hours.

# %%
# Triangular distribution parameters
a = 4
b = 10
c = 6

def triangular_cdf(x, a, b, c):
    if x < a:
        return 0
    elif a <= x <= c:
        return ((x - a) ** 2) / ((b - a) * (c - a))
    elif c < x <= b:
        return 1 - ((b - x) ** 2) / ((b - a) * (b - c))
    else:
        return 1

F_5 = triangular_cdf(5, a, b, c)
F_8 = triangular_cdf(8, a, b, c)

probability = F_8 - F_5

print("F(5) =", F_5)
print("F(8) =", F_8)
print("P(5 <= X <= 8) =", probability)
# Out:
# F(5) = 0.08333333333333333
# F(8) = 0.8333333333333334
# P(5 <= X <= 8) = 0.75

# %% [markdown]
# #10

# %% [markdown]
# ### Use in Project Planning
#
# The Triangular distribution is useful because it uses three simple estimates:
#
# $$
# a=\text{best-case time},\qquad
# b=\text{worst-case time},\qquad
# c=\text{most likely time}.
# $$
#
# It helps estimate the expected completion time and the probability of finishing before a deadline. In sensitivity analysis, changing \(a\), \(b\), or \(c\) shows how the project schedule changes under different assumptions.

# %% [markdown]
# Q6) Expected Project Completion Time Using PERT

# %% [markdown]
# A project manager is estimating the time required to complete a critical software integration task. Let $X$ denote the number of days required to complete the task. Based on expert judgment, the shortest possible time is $a=8$ days, the longest possible time is $b=20$ days, and the most likely completion time is $c=11$ days. Assume that $X$ follows a PERT distribution with parameters $(a,b,c)$.
#
# The PERT distribution is defined as a Beta distribution scaled to the interval $[a,b]$, with internal shape parameters
#
# $$
# \alpha = 1 + 4\left( \frac{c-a}{b-a} \right)
# $$
#
# and
#
# $$
# \beta = 1 + 4\left( \frac{b-c}{b-a} \right).
# $$
#
# Its probability density function is
#
# $$
# f(x)=\frac{(x-a)^{\alpha-1}(b-x)^{\beta-1}}{B(\alpha,\beta)(b-a)^{\alpha+\beta-1}}, \qquad a \leq x \leq b,
# $$
#
# where
#
# $$
# B(\alpha,\beta)=\int_0^1 t^{\alpha-1}(1-t)^{\beta-1},dt.
# $$
#
# Answer the following:
#
# 1. Compute the values of the shape parameters $\alpha$ and $\beta$.
#
# 2. Specify the support of $X$.
#
# 3. Write down the probability density function $f_X(x)$ for this model.
#
# 4. State the probability space $(\Omega,\mathfrak F,P)$ suitable for this continuous model.
#
# 5. Define $X$ as a random variable on this space.
#
# 6. Show that the expectation $E[X]$ is
#
# $$
# E[X]=\frac{a+4c+b}{6}.
# $$
#
# 7. Compute the variance $\mathrm{Var}(X)$ using the approximation
#
# $$
# \mathrm{Var}(X)=\frac{(E[X]-a)(b-E[X])}{7}.
# $$
#
# 8. Compute the approximate standard deviation $\sigma$.
#
# 9. Briefly explain why a PERT distribution may be more appropriate than a Triangular distribution in this setting byt comparing the two results.
#
# 10. Interpret the practical meaning of the values $a$, $b$, $c$, $E[X]$, and $\sigma$ in the context of project planning.

# %% [markdown]
# #1

# %% [markdown]
# ### Shape Parameters of the PERT Distribution
#
# Given
#
# $$
# a=8,\qquad b=20,\qquad c=11,
# $$
#
# the shape parameters are defined as
#
# $$
# \alpha=1+4\left(\frac{c-a}{b-a}\right)
# $$
#
# and
#
# $$
# \beta=1+4\left(\frac{b-c}{b-a}\right).
# $$
#
# First,
#
# $$
# b-a=20-8=12.
# $$
#
# Now,
#
# $$
# \alpha=1+4\left(\frac{11-8}{20-8}\right)
# =
# 1+4\left(\frac{3}{12}\right).
# $$
#
# Thus,
#
# $$
# \alpha=1+4(0.25)=1+1=2.
# $$
#
# Therefore,
#
# $$
# \boxed{\alpha=2}.
# $$
#
# Next,
#
# $$
# \beta=1+4\left(\frac{20-11}{20-8}\right)
# =
# 1+4\left(\frac{9}{12}\right).
# $$
#
# Thus,
#
# $$
# \beta=1+4(0.75)=1+3=4.
# $$
#
# Therefore,
#
# $$
# \boxed{\beta=4}.
# $$
#
# Hence, the shape parameters are
#
# $$
# \boxed{\alpha=2,\qquad \beta=4}.
# $$

# %% [markdown]
# #2

# %% [markdown]
# ### Support of $X$
#
# The PERT distribution is defined on the interval \([a,b]\), where \(a\) is the shortest possible time and \(b\) is the longest possible time.
#
# Given
#
# $$
# a=8,\qquad b=20,
# $$
#
# the support of \(X\) is
#
# $$
# \boxed{X\in[8,20]}.
# $$
#
# Thus, the software integration task can take between \(8\) days and \(20\) days.

# %% [markdown]
# #3
